# %%
# General Import

import pandas as pd
import numpy as np
import re
import seaborn as sns

#!pip install scipy
import scipy
pearsonr = scipy.stats.pearsonr

import matplotlib.pyplot as plt 
import matplotlib.dates as mdates
# %matplotlib inline

# %%
# %run /home/ubuntu/notebooks/covid-prj01-data-analysis/[UTILS]/dremio-access-new.py

dremio = DremioQueryMakerJDBC()
index = dremio.getIndex()
display(index)
# Out:
#    TABLE_CATALOG                                       TABLE_SCHEMA  \
# 0         DREMIO                                         Covid-Lake
# 1         DREMIO                                         Covid-Lake
# 2         DREMIO                                         Covid-Lake
# 3         DREMIO                                         Covid-Lake
# 4         DREMIO                                         Covid-Lake
# 5         DREMIO                                      covidlake-raw
# 6         DREMIO                                      covidlake-raw
# 7         DREMIO                                      covidlake-raw
# 8         DREMIO                                      covidlake-raw
# 9         DREMIO                                      covidlake-raw
# 10        DREMIO                                      covidlake-raw
# 11        DREMIO                                      covidlake-raw
# 12        DREMIO                                      covidlake-raw
# 13        DREMIO                                      covidlake-raw
# 14        DREMIO                                      covidlake-raw
# 15        DREMIO                                  covidlake-refined
# 16        DREMIO                Common Data Model.disease_indicator
# 17        DREMIO                                  covidlake-raw.ans
# 18        DREMIO                          covidlake-raw.BigDataCorp
# 19        DREMIO                          covidlake-raw.BigDataCorp
# 20        DREMIO                              covidlake-raw.datasus
# 21        DREMIO                              covidlake-raw.datasus
# 22        DREMIO                              covidlake-raw.datasus
# 23        DREMIO                              covidlake-raw.datasus
# 24        DREMIO                              covidlake-raw.datasus
# 25        DREMIO                              covidlake-raw.datasus
# 26        DREMIO                              covidlake-raw.datasus
# 27        DREMIO                              covidlake-raw.datasus
# 28        DREMIO                              covidlake-raw.datasus
# 29        DREMIO                              covidlake-raw.datasus
# 30        DREMIO                              covidlake-raw.datasus
# 31        DREMIO                        covidlake-raw.transparencia
# 32        DREMIO                        covidlake-raw.transparencia
# 33        DREMIO                        covidlake-raw.transparencia
# 34        DREMIO                        covidlake-raw.transparencia
# 35        DREMIO      Common Data Model.disease_indicator.brasil_io
# 36        DREMIO      Common Data Model.disease_indicator.brasil_io
# 37        DREMIO  Common Data Model.disease_indicator.health_min...
# 38        DREMIO  Common Data Model.disease_indicator.health_min...
# 39        DREMIO          Common Data Model.disease_indicator.wcota
# 40        DREMIO          Common Data Model.disease_indicator.wcota
# 41        DREMIO  Common Data Model.Institutions.hospitals_register
# 42        DREMIO  Common Data Model.Institutions.hospitals_register
# 43        DREMIO        Common Data Model.news_trends.google_trends
# 44        DREMIO        Common Data Model.news_trends.google_trends
# 45        DREMIO   Common Data Model.socioeconomic_factors.ipeadata
# 46        DREMIO   Common Data Model.socioeconomic_factors.ipeadata
# 47        DREMIO  Common Data Model.disease_indicator.brasil_io....
# 48        DREMIO  Common Data Model.disease_indicator.brasil_io....
# 49        DREMIO  Common Data Model.disease_indicator.health_min...
# 50        DREMIO  Common Data Model.disease_indicator.health_min...
# 51        DREMIO  Common Data Model.disease_indicator.wcota.stan...
# 52        DREMIO  Common Data Model.disease_indicator.wcota.stan...
# 53        DREMIO  Common Data Model.Institutions.hospitals_regis...
# 54        DREMIO  Common Data Model.Institutions.hospitals_regis...
# 55        DREMIO  Common Data Model.news_trends.google_trends.st...
# 56        DREMIO  Common Data Model.socioeconomic_factors.ipeada...
#
#                                            TABLE_NAME  \
# 0                                   Disease_Indicator
# 1                                     hospitalizações
# 2                                         Institution
# 3                                         News&Trends
# 4                               Socioeconomic_Factors
# 5                                           brasil_io
# 6                                              cities
# 7                                   fiocruz_infogripe
# 8                                       google_trends
# 9                                     health_ministry
# 10                                hospitals_dimension
# 11                                     mobility_apple
# 12                                    mobility_google
# 13                                             pebmed
# 14                                              wcota
# 15                                       observations
# 16                                     global_dataset
# 17                      demandas_dos_consumidores_nip
# 18                                treatedBDCcompanies
# 19                                   treatedBDCpeople
# 20  cadasto_nacional_de_estabelecimentos_de_saude_...
# 21  cadasto_nacional_de_estabelecimentos_de_saude_...
# 22  cobertura_estimada_da_populacao_residente_pela...
# 23   distribuicao_das_equipes_de_saude_da_familia_esf
# 24  distribuicao_de_agentes_comunitarios_de_saude_acs
# 25  distribuicao_dos_nucles_de_apoio_a_saude_da_fa...
# 26  distribuicao_unidades_basicas_de_saude_em_func...
# 27  distribuicao_unidaes_basicas_de_saude_existent...
# 28          numero_de_equipes_da_saude_da_familia_esf
# 29  numero_de_equipes_de_agentes_comunitarios_de_s...
# 30  numero_de_unidades_basicas_de_saude_em_constru...
# 31            transparencia_auxilio_emergencial_abril
# 32            transparencia_auxilio_emergencial_julho
# 33            transparencia_auxilio_emergencial_junho
# 34             transparencia_auxilio_emergencial_maio
# 35                                     logical_entity
# 36                                    physical_entity
# 37                                     logical_entity
# 38                                    physical_entity
# 39                                     logical_entity
# 40                                    physical_entity
# 41                                     logical_entity
# 42                                    physical_entity
# 43                                     logical_entity
# 44                                    physical_entity
# 45                                     logical_entity
# 46                                    physical_entity
# 47                                           Location
# 48                                        Observation
# 49                                           Location
# 50                                        Observation
# 51                                           Location
# 52                                        Observation
# 53                                           Location
# 54                                       Organization
# 55                                        Observation
# 56                                        Observation
#
#                                       VIEW_DEFINITION
# 0   SELECT createdOn, identifier, valueString, val...
# 1                 SELECT * FROM "hospitalizacoes.csv"
# 2                        SELECT * FROM logical_entity
# 3                        SELECT * FROM logical_entity
# 4   SELECT createdOn, clean_data_to_FLOAT(valueStr...
# 5                          SELECT *\nFROM "brasil.io"
# 6     SELECT * FROM "Base Coordenadas Brasil.parquet"
# 7                     SELECT * FROM fiocruz_infogripe
# 8               SELECT * FROM "google_trends.parquet"
# 9                       SELECT * FROM health_ministry
# 10                  SELECT * FROM "hospitals.parquet"
# 11                SELECT * FROM apple_mobility_trends
# 12  SELECT * FROM "covid-raw".mobility.google."Glo...
# 13                               SELECT * FROM pebmed
# 14                                SELECT * FROM wcota
# 15  SELECT "date" as createdOn, 'brasil.io' as ide...
# 16  SELECT createdOn, identifier, valueString, val...
# 17        SELECT * FROM demandas_dos_consumidores_nip
# 18  SELECT STATE, CASE WHEN regexp_like(CASE WHEN ...
# 19  SELECT STATE, EMPLOYMENT_STABILITY_2020_01_01,...
# 20  SELECT * FROM "cadasto_nacional_de_estabelecim...
# 21  SELECT * FROM "cadasto_nacional_de_estabelecim...
# 22  SELECT * FROM "cobertura_estimada_da_populacao...
# 23  SELECT * FROM "distribuicao_das_equipes_de_sau...
# 24  SELECT * FROM "distribuicao_de_agentes_comunit...
# 25  SELECT * FROM "distribuicao_dos_nucles_de_apoi...
# 26  SELECT * FROM "distribuicao_unidades_basicas_d...
# 27  SELECT * FROM "distribuicao_unidaes_basicas_de...
# 28  SELECT * FROM "numero_de_equipes_da_saude_da_f...
# 29  SELECT * FROM "numero_de_equipes_de_agentes_co...
# 30  SELECT * FROM "numero_de_unidades_basicas_de_s...
# 31  SELECT * FROM "abril_auxilio_emergencial.parquet"
# 32  SELECT * FROM "julho_auxilio_emergencial.parquet"
# 33  SELECT * FROM "julho_auxilio_emergencial.parquet"
# 34   SELECT * FROM "maio_auxilio_emergencial.parquet"
# 35  SELECT *\nFROM "standard_entities".Observation...
# 36  SELECT index, TO_CHAR(TO_DATE(nested_0."date",...
# 37  SELECT *\nFROM "standard_entities".Observation...
# 38  SELECT src2.*, location_id\nFROM (\n    SELECT...
# 39  SELECT *\nFROM "standard_entities".Observation...
# 40  SELECT src2.*, location_id\nFROM (\n    SELECT...
# 41  SELECT userGroupId, name, localeId, loc.*\nFRO...
# 42  SELECT nested_1.CO_UNIDADE AS CO_UNIDADE, nest...
# 43                          SELECT * FROM Observation
# 44              SELECT * FROM "google_trends.parquet"
# 45                          SELECT * FROM Observation
# 46  SELECT index, ipeadata."DATE" AS "DATE", ipead...
# 47  SELECT location_id as locationId, '' as addres...
# 48  SELECT "date" as createdOn, 'brasil.io' as ide...
# 49  SELECT location_id as locationId, '' as addres...
# 50  SELECT "date" as createdOn, 'health_ministry' ...
# 51  SELECT location_id as locationId, country as a...
# 52  SELECT "date" as createdOn, 'wcota' as identif...
# 53  SELECT CO_UNIDADE AS organizationId, \n       ...
# 54  SELECT CO_UNIDADE AS organizationId, CO_CNES A...
# 55  SELECT "Date" as createdOn, CAST(Medicamento a...
# 56  SELECT "DATE" as createdOn, "VALUE" as valueSt...

# %%
brasil_io = dremio.getTable(35)

# %%
health_ministry = dremio.getTable(37)

# %%
display(health_ministry.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b94fd3ccc623> in <module>
# ----> 1 display(health_ministry.head())
#
# NameError: name 'health_ministry' is not defined

# %%
print('FIM')
# Out:
# FIM
